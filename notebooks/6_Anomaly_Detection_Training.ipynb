# %%
# %load_ext autoreload
# %autoreload

import numpy as np
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from anomalyzer.config import loader
from anomalyzer.evaluate_performance import evaluate_performance
from anomalyzer.prepare_data import prepare_data

# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, roc_auc_score

from sklearn.decomposition import PCA

from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.covariance import EllipticEnvelope
from sklearn.neighbors import LocalOutlierFactor

# %% [markdown]
# ### Load the data

# %%
day_of_week = 'Tuesday'

data_file= loader(day_of_week=day_of_week,data_type='processed',subtype='Normalized')

df=pd.read_pickle(data_file)

# %% [markdown]
# ## Preparing the Dataset for Anomaly Detection
#
# Here we need to separate our class variable, which in our case is "Label" from the rest of the dataset.
#
# Anomaly detection algorithms output +1 for inlier and -1 for outliers. Therefore:
#
# 1. We need to map multiple classes to binary classes.
# 2. Since we are interesting in detecting anomalies, the negative class is 'BENIGN'.

# %%
X,y=prepare_data(data=df,class_column='Label',job='anomaly',classes='binary',neg_class='BENIGN')

# %% [markdown]
# ### Subset: Dimensionality Reduction w/ PCA
#
# We first implement PCA on the dataset to reduce the number of features. The number of features is informed by the feature ranking provided by the xgboost models trained on the dataset.

# %%
new_dimension = 28 #Choose the number of features for PCA

pca_model = PCA(n_components=new_dimension, random_state=4162)
x_red_pca = pca_model.fit_transform(X)

# %% [markdown]
# ## 1. Training the Isolation Forest Method
#
# We train an Isolation Forest model to detect anomalies in the dataset. Returns -1 for outlier and 1 for inliers.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html

# %% [markdown]
# ### Train and save the model
#
# We first train our model and pickle save it for future retrieval.
#
# The contamination parameter of the model is the expected fraction of outliers in the dataset and should be adjusted if necessary.

# %%
isf = IsolationForest(contamination=0.05, behaviour='new', random_state=42, n_jobs=3)
isf.fit(x_red_pca)

filename='./models/isf_model_'+day_of_week+'_PCA_'+str(new_dimension)+'.pkl'

with open(filename,'wb') as file:
    pickle.dump(isf,file)

# %% [markdown]
# ### Predict anomalies
#
# Returns 1 for inlier and -1 for outlier (aka anomalies)

# %%
isf_anomalies = isf.predict(x_red_pca)
isf_anomalies
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# ### Performance measures
#
# We choose to investigate the performance using
#
# 1. Confusion Matrix (full picture of anomaly classification)
# 2. Accuracy
# 3. Precision of the anomaly class
# 4. Recall on the anomaly class
# 5. F-1 Measure on the anomaly class
# 6. AUC score

# %%
confusion_matrix(y,isf_anomalies,labels=[-1,1])
# Out:
# array([[ 22156, 409657],
#        [   121,  13711]], dtype=int64)

# %%
evaluate_performance(y,isf_anomalies)
# Out:
# Accuracy: 0.08
# Precision: 0.995
# Recall: 0.051
# f-1 score: 0.098
# AUC score: 0.521

# %% [markdown]
# ## 2. Training the one-class SVM Method
#
# We train an one class SVM model to detect anomalies in the dataset. Returns -1 for outlier and 1 for inliers.
#
# See: https://scikit-learn.org/stable/modules/generated/sklearn.svm.OneClassSVM.html#sklearn.svm.OneClassSVM

# %% [markdown]
# ### Train and save the model
#
# We first train our model and pickle save it for future retrieval. The kernel choice is **Radial Basis Function** ('rbf) as we would like to have locality in the decision boundaries learned by our SVM.

# %%
svm_model=OneClassSVM(kernel='rbf',gamma='auto')
svm_model.fit(x_red_pca)

filename='./models/svm_model'+day_of_week+'.pkl'

with open(filename,'wb') as file:
    pickle.dump(svm_model,file)
# Out:
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\svm\classes.py:1185: DeprecationWarning: The random_state parameter is deprecated and will be removed in version 0.22.
#   " be removed in version 0.22.", DeprecationWarning)

# %% [markdown]
# ### Predict anomalies
#
# Returns 1 for inlier and -1 for outlier (aka anomalies)

# %%
svm_anomalies = svm_model.predict(x_red_pca)
svm_anomalies

# %% [markdown]
# ### Performance measures
#
# We choose to investigate the performance using
#
# 1. Confusion Matrix (full picture of anomaly classification)
# 2. Accuracy
# 3. Precision of the anomaly class
# 4. Recall on the anomaly class
# 5. F-1 Measure on the anomaly class
# 6. AUC score

# %%
evaluate_performance(y,svm_anomalies,3)

# %% [markdown]
# ## 3. Training the Elliptic Envelope method.
#
# We train an an Elliptic envelope model designed to detect outliers in a Gaussian distributed dataset.
#
# Returns -1 for outlier and 1 for inliers.
#
# See: https://scikit-learn.org/stable/modules/generated/sklearn.covariance.EllipticEnvelope.html

# %% [markdown]
# ### Train and save the model
#
# We first train our model and pickle save it for future retrieval.
#
# The contamination parameter of the model is the expected fraction of outliers in the dataset and should be adjusted if necessary.

# %%
cov = EllipticEnvelope(contamination=0.1,random_state=0)
cov.fit(x_red_pca)

filename='./models/cov_model_'+day_of_week+'_PCA_'+str(new_dimension)+'.pkl'

with open(filename,'wb') as file:
    pickle.dump(cov,file)
# Out:
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-127.305356030749138 > -133.414774938987819). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-124.413306475327914 > -133.099246710330760). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-172.813113491074148 > -172.842086559922109). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-172.985786324910862 > -172.987872582491718). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-163.563039195263173 > -163.624564352616318). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-163.518992268961540 > -163.587932780862786). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-161.591994722624776 > -161.637288150770530). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-158.849247086805150 > -158.927768710370742). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-160.976752376125944 > -161.049052257620218). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-160.649710030359699 > -160.721191642071318). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-160.744203612120373 > -160.767717413031306). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-165.738933112840925 > -166.715673618033435). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-174.726796835822114 > -174.846835388662498). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-174.726062806581638 > -174.736732497853694). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-171.722382889791021 > -171.743365952710292). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-160.680234591037163 > -160.753805666629631). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-156.405385235621395 > -156.470646832320114). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-134.994693213032832 > -135.435528239019334). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-130.912242197057992 > -142.536677748473920). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-130.737127041703474 > -138.448229647530468). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-174.776710195503796 > -174.795965389131283). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-174.335318852905431 > -174.352006112054426). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-164.183787561905717 > -165.181398575910379). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-163.203533770365539 > -163.295214010163136). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-160.759180201002010 > -160.783041970915832). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-160.789789650135589 > -160.913798760069568). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-173.308273663508970 > -173.316576200334083). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-174.797404994588561 > -174.824690304725777). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-172.108032901658703 > -172.130130881243531). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-127.188623348182901 > -128.421404506769392). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-163.948380653574588 > -163.958453804496287). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-162.655440649187938 > -162.987687920986019). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-164.128792622090828 > -164.137505383792956). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-161.953102714755971 > -161.997306160165664). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-139.039116339100758 > -141.827843768782571). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-165.697121931860323 > -167.036609873850864). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-156.833995587469303 > -156.904212957361352). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-164.012737257803025 > -165.431850045699406). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-158.546571794443253 > -158.555870210656849). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-158.476359220250686 > -158.521561618665885). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-172.074954940934617 > -172.093304742937107). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-158.893872796789935 > -158.911224214485600). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\emirk\Anaconda3\envs\insight\lib\site-packages\sklearn\covariance\robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-159