# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 10]

# %%
day_of_week='Wednesday'

data_directory='../data/processed'
file_name=day_of_week+'_processed.pkl'

data_file=os.path.join(data_directory,file_name)

# %%
df=pd.read_pickle(data_file)

# %% [markdown]
# ## Correlation Analysis
#
# We investigate the correlation among the features in the dataset to check for multicollinearity issues. However, as we will be implementing dimensionality reduction with this dataset, manually removing features is not done at this point.

# %%
correlation_matrix=df.corr()

# %%
correlation_matrix
# Out:
#                              Destination Port  Flow Duration  \
# Destination Port                     1.000000      -0.345753
# Flow Duration                       -0.345753       1.000000
# Total Fwd Packets                   -0.281936       0.718741
# Total Backward Packets              -0.269448       0.756913
# Total Length of Fwd Packets         -0.232387       0.691715
# ...                                       ...            ...
# Active Min                          -0.199196       0.784382
# Idle Mean                           -0.213885       0.830668
# Idle Std                            -0.094253       0.341623
# Idle Max                            -0.213891       0.830687
# Idle Min                            -0.213865       0.830592
#
#                              Total Fwd Packets  Total Backward Packets  \
# Destination Port                     -0.281936               -0.269448
# Flow Duration                         0.718741                0.756913
# Total Fwd Packets                     1.000000                0.709164
# Total Backward Packets                0.709164                1.000000
# Total Length of Fwd Packets           0.709028                0.840186
# ...                                        ...                     ...
# Active Min                            0.715669                0.646896
# Idle Mean                             0.718738                0.645658
# Idle Std                              0.447277                0.381999
# Idle Max                              0.718841                0.645397
# Idle Min                              0.718419                0.645901
#
#                              Total Length of Fwd Packets  \
# Destination Port                               -0.232387
# Flow Duration                                   0.691715
# Total Fwd Packets                               0.709028
# Total Backward Packets                          0.840186
# Total Length of Fwd Packets                     1.000000
# ...                                                  ...
# Active Min                                      0.580580
# Idle Mean                                       0.578522
# Idle Std                                        0.322755
# Idle Max                                        0.578431
# Idle Min                                        0.578579
#
#                              Total Length of Bwd Packets  \
# Destination Port                               -0.376741
# Flow Duration                                   0.750671
# Total Fwd Packets                               0.662620
# Total Backward Packets                          0.902331
# Total Length of Fwd Packets                     0.827051
# ...                                                  ...
# Active Min                                      0.633323
# Idle Mean                                       0.663314
# Idle Std                                        0.201006
# Idle Max                                        0.662917
# Idle Min                                        0.663888
#
#                              Fwd Packet Length Max  Fwd Packet Length Min  \
# Destination Port                         -0.220012              -0.011122
# Flow Duration                             0.727361              -0.392743
# Total Fwd Packets                         0.683488              -0.596040
# Total Backward Packets                    0.832222              -0.275688
# Total Length of Fwd Packets               0.970560              -0.123176
# ...                                            ...                    ...
# Active Min                                0.620042              -0.470508
# Idle Mean                                 0.631730              -0.503037
# Idle Std                                  0.270671              -0.208944
# Idle Max                                  0.631487              -0.503042
# Idle Min                                  0.632063              -0.503016
#
#                              Fwd Packet Length Mean  Fwd Packet Length Std  \
# Destination Port                          -0.186726              -0.104079
# Flow Duration                              0.538319               0.747355
# Total Fwd Packets                          0.429020               0.815393
# Total Backward Packets                     0.671502               0.734179
# Total Length of Fwd Packets                0.919200               0.781327
# ...                                             ...                    ...
# Active Min                                 0.386859               0.704817
# Idle Mean                                  0.390252               0.733711
# Idle Std                                   0.145690               0.277683
# Idle Max                                   0.390148               0.733534
# Idle Min                                   0.390455               0.733974
#
#                              ...  act_data_pkt_fwd  min_seg_size_forward  \
# Destination Port             ...         -0.217380             -0.058164
# Flow Duration                ...          0.591117             -0.114822
# Total Fwd Packets            ...          0.795401             -0.082249
# Total Backward Packets       ...          0.738207             -0.136587
# Total Length of Fwd Packets  ...          0.816866             -0.190634
# ...                          ...               ...                   ...
# Active Min                   ...          0.532013             -0.110391
# Idle Mean                    ...          0.497310             -0.080964
# Idle Std                     ...          0.370354             -0.014360
# Idle Max                     ...          0.497289             -0.080746
# Idle Min                     ...          0.497191             -0.081324
#
#                              Active Mean  Active Std  Active Max  Active Min  \
# Destination Port               -0.198998   -0.088543   -0.198801   -0.199196
# Flow Duration                   0.783567    0.318189    0.782701    0.784382
# Total Fwd Packets               0.717516    0.438952    0.718164    0.715669
# Total Backward Packets          0.646546    0.421142    0.647382    0.646896
# Total Length of Fwd Packets     0.581923    0.360598    0.582516    0.580580
# ...                                  ...         ...         ...         ...
# Active Min                      0.999296    0.422874    0.999147    1.000000
# Idle Mean                       0.945520    0.360457    0.944350    0.946726
# Idle Std                        0.461281    0.931419    0.467409    0.449094
# Idle Max                        0.945611    0.360936    0.944443    0.946769
# Idle Min                        0.945301    0.359157    0.944119    0.946576
#
#                              Idle Mean  Idle Std  Idle Max  Idle Min
# Destination Port             -0.213885 -0.094253 -0.213891 -0.213865
# Flow Duration                 0.830668  0.341623  0.830687  0.830592
# Total Fwd Packets             0.718738  0.447277  0.718841  0.718419
# Total Backward Packets        0.645658  0.381999  0.645397  0.645901
# Total Length of Fwd Packets   0.578522  0.322755  0.578431  0.578579
# ...                                ...       ...       ...       ...
# Active Min                    0.946726  0.449094  0.946769  0.946576
# Idle Mean                     1.000000  0.388170  0.999996  0.999985
# Idle Std                      0.388170  1.000000  0.389221  0.385666
# Idle Max                      0.999996  0.389221  1.000000  0.999969
# Idle Min                      0.999985  0.385666  0.999969  1.000000
#
# [67 rows x 67 columns]

# %%
fig=plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix,cmap='viridis')

# %% [markdown]
# As suspected there seems to be a high level of correlation with many of the features in our dataset.

# %% [markdown]
# ## Distinguishing features per class variable.
#
# Finally, we plot histograms where features have been separated per class variable to explore the discriminating power per feature.
#
# We start by separating the data frames per class label in a dictionary.

# %%
df_per_class={}

for label in df['Label'].unique():
    df_per_class[label]=df.loc[df['Label']==label]

# %%
df_per_class.keys()
# Out:
# dict_keys(['BENIGN', 'DoS slowloris', 'DoS Slowhttptest', 'DoS Hulk', 'DoS GoldenEye', 'Heartbleed'])

# %%
df_per_class['BENIGN'].head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                80      -0.171623          -1.525682               -0.537383
# 1               389      -0.857651           1.353208                0.711236
# 2                88      -0.733438           1.277448                0.859972
# 3               389      -0.322022           1.654655                1.401459
# 4                88      -0.733854           1.189372                0.859972
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                    -0.985881                    -0.854012
# 1                     0.333602                     0.161480
# 2                     1.877072                     0.812508
# 3                     1.932152                     1.036734
# 4                     1.877072                     0.812696
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0              -0.906670               0.699029               -0.825948
# 1               0.152381              -0.825974               -0.337056
# 2               1.874575              -0.825974                2.014803
# 3               1.753461              -0.825974                1.583637
# 4               1.874575              -0.825974                2.123422
#
#    Fwd Packet Length Std  ...  min_seg_size_forward  Active Mean  Active Std  \
# 0              -0.892973  ...             -1.068829    -0.668233   -0.262388
# 1               0.732250  ...              0.833512    -0.668233   -0.262388
# 2               1.491230  ...              0.833512    -0.668233   -0.262388
# 3               1.412771  ...              0.833512    -0.668233   -0.262388
# 4               1.508930  ...              0.833512    -0.668233   -0.262388
#
#    Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min   Label
# 0   -0.667497   -0.668941  -0.704934   -0.2817 -0.704936 -0.704909  BENIGN
# 1   -0.667497   -0.668941  -0.704934   -0.2817 -0.704936 -0.704909  BENIGN
# 2   -0.667497   -0.668941  -0.704934   -0.2817 -0.704936 -0.704909  BENIGN
# 3   -0.667497   -0.668941  -0.704934   -0.2817 -0.704936 -0.704909  BENIGN
# 4   -0.667497   -0.668941  -0.704934   -0.2817 -0.704936 -0.704909  BENIGN
#
# [5 rows x 68 columns]

# %% [markdown]
# One particularly interesting way to obtain a sense of how well different features separate per class label, we can use the distribution plot from the seaborn library.
#
# See: https://seaborn.pydata.org/generated/seaborn.distplot.html
#
# In addition to a histogram, this plotting method also provides us with a Gaussian Kernel Density Estimator which is useful for inspecting the differences in distibutions per feature per class label.

# %%
fig=plt.figure()
for label in df['Label'].unique():
    sns.distplot(df_per_class[label]['Total Fwd Packets'].values,hist=True,kde=True)
    plt.legend(df_per_class.keys())

# %% [markdown]
# We then save the distribution plots in their own folder for future references.

# %%
for index, feature in enumerate(df.columns.values[0:-1],1):
    fig=plt.figure()
    for label in df['Label'].unique():
        sns.distplot(df_per_class[label][feature],bins=10)
    plt.title(feature+' distribution across class labels')
    plt.legend(df_per_class.keys())
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.show()
    plt.savefig('./figures/'+day_of_week+'/per_class_features/'+str(index)+'_'+feature+'_Histogram.png')
    plt.close(fig)
